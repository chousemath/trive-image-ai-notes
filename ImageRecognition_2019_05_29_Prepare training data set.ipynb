# %%
# import all dependencies here
import os
import pandas as pd
import shutil
import random
import sys
from pprint import pprint
import typing as T
import cv2
import shutil
import string

# %%
ROOT = '/Volumes/TriveStorage/code/trive-image-recognition/complete_manual/directional_cleaned'
directions = ['front', 'back', 'side', 'mix', 'front_hflip', 'back_hflip', 'side_hflip', 'mix_hflip']
processed_folders = [x for x in os.listdir(ROOT) if '.DS_Store' not in x]

# %%
data = []
full_total = 0
for processed_folder in processed_folders:
    if '_' in processed_folder:
        shutil.rmtree(os.path.join(ROOT, processed_folder), ignore_errors=True)
        continue
    
    image_counts = []
    image_total = 0
    image_counts.append(processed_folder)
    for direction in directions:
        direction_path = os.path.join(ROOT, processed_folder, direction)
        if not os.path.exists(direction_path):
            os.mkdir(direction_path)
        image_paths = [os.path.join(direction_path, s) for s in os.listdir(direction_path)]
        image_counts.append(len(image_paths))
    total = sum(image_counts[1:5])
    full_total += total
    image_counts.append(total)
    image_counts.append(sum(image_counts[1:9]))
    data.append(image_counts)

# %%
headers = ['name', 'front', 'back', 'side', 'mix', 'front_hflip', 'back_hflip', 'side_hflip', 'mix_hflip', 'total', 'totalWithAug']
df = pd.DataFrame(data, columns=headers)
df['side'] = df['side'] + df['mix']
df = df.drop(columns='mix')

# %%
# figure out how much data augmentation is required for each
# vehicle class
# * xxxAug = 0, indicates no augmentation is required
# * yyyAug = 100, indicates that 100 additional images are required

training_image_req = 334 # 1000 / 3
test_image_req = 67 # 200 / 3

image_requirement = training_image_req + test_image_req

df['frontAug'] = image_requirement - df['front']
df.loc[df['frontAug']<0,'frontAug'] = 0

df['backAug'] = image_requirement - df['back']
df.loc[df['backAug']<0,'backAug'] = 0

df['sideAug'] = image_requirement - df['side']
df.loc[df['sideAug']<0,'sideAug'] = 0

# %%
# df['augTotal'] = df['frontAug'] + df['backAug'] + df['sideAug']
df = df.sort_values(by='total', ascending=False)

# %%
df.to_csv('/Users/jo/Desktop/trive-image-recognition-logic/image_counts.csv', sep=',', index=False)
df['name'].to_csv('/Users/jo/Desktop/trive-image-recognition-logic/class_names.csv', sep=',', index=False)
top_100 = df.head(10000)
# top_100 = top_100[(top_100['total'] < 1200) & (top_100['totalWithAug'] < 1200) & (top_100['total'] >= 600)]
# top_100 = top_100[(top_100['total'] >= 1200) | (top_100['totalWithAug'] >= 1200)]
names = list(df['name'].values)
with open('current_vehicle_names.txt', 'w') as f:
    for item in names:
        f.write(f'{item}\n')

top_100.to_csv(r'/Users/jo/Desktop/trive-image-recognition-logic/top_200.csv', index = None, header=True)
print('number of classes:', len(top_100.index))
print('full total: ', full_total)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(top_100)
# Out:
# number of classes: 619
# full total:  197169
#                                                   name  front  back  side  \
# 58                              기아레이레이(11~17년)   1187  1474  2420
# 82                     기아스포티지스포티지R(10~13년)    913   917  2445
# 68                       기아모닝올뉴모닝(11~15년)    757  1073  2093
# 105                  기아카니발올뉴카니발(14~18년)   1179   842  1646
# 572             현대아반떼더뉴아반떼AD(18년~현재)    460   692  2331
# 80                 기아스포티지더뉴스포티지R(13~15년)    849   865  1410
# 102                기아카니발그랜드카니발(05~10년)    635   926  1509
# 91                   기아쏘렌토올뉴쏘렌토(14~17년)    579   794  1533
# 201                      르노삼성SM6SM6(16년~현재)    872   456  1463
# 39                             기아K5K52세대(15~18년)    929   631  1047
# 43                              기아K5더뉴K5(13~15년)    769   663  1138
# 69                기아모닝올뉴모닝(JA)(17년~현재)    878   586  1063
# 81                 기아스포티지스포티지4세대(15~18년)    462   564  1390
# 48                              기아K7더뉴K7(12~16년)    694   600  1066
# 12                    BMW5시리즈5시리즈(F10)(10~16년)    407   361  1578
# 50                          기아K7올뉴K7(16년~현재)    765   536  1040
# 90                       기아쏘렌토쏘렌토R(09~12년)    512   526  1239
# 71                          기아모하비모하비(07~16년)    603   643   905
# 556                      현대쏘나타LF쏘나타(14~17년)    544   359  1104
# 562                현대쏘나타쏘나타(DN8)(19년~현재)    566   607   820
# 605                  현대투싼올뉴투싼(15년~현재)    481   326  1172
# 107                      기아카니발카니발R(10~14년)    487   581   870
# 440                        제네시스G80G80(16년~현재)    756   592   490
# 438                       제네시스EQ900EQ900(15~18년)    660   519   522
# 560                      현대쏘나타YF쏘나타(09~12년)    580   448   669
# 567              현대쏘나타쏘나타하이브리드(11~14년)    423   491   782
# 577                    현대아반떼아반떼MD(10~13년)    519   563   586
# 551                    현대싼타페싼타페CM(05~12년)    354   382   899
# 576                    현대아반떼아반떼HD(06~10년)    179   311  1144
# 79                   기아스포티지New스포티지(04~10년)    354   437   794
# 552                    현대싼타페싼타페DM(12~15년)    612   386   561
# 194                       르노삼성SM3뉴SM3(09~14년)    381   258   875
# 55                              기아니로니로(16~19년)    193   206  1113
# 66                        기아모닝더뉴모닝(15~17년)    380   409   709
# 200             르노삼성SM5뉴SM5플래티넘(12~15년)    341   344   808
# 320               쉐보레(GM대우)스파크스파크(11~15년)    396   365   709
# 318      쉐보레(GM대우)스파크더넥스트스파크(15~18년)    326   477   665
# 574                    현대아반떼아반떼AD(15~18년)    452   401   608
# 65                          기아모닝뉴모닝(08~11년)    348   398   701
# 553                 현대싼타페싼타페TM(18년~현재)    418   372   655
# 87                     기아쏘렌토뉴쏘렌토R(12~14년)    397   330   718
# 46                                  기아K7K7(09~11년)    462   332   632
# 49                      기아K7더프레스티지K7(11~12년)    317   217   870
# 70                   기아모하비더뉴모하비(16년~현재)    405   381   600
# 108                     기아카렌스뉴카렌스(06~13년)    564   403   382
# 554             현대싼타페싼타페더프라임(15~18년)    369   357   569
# 596                    현대제네시스제네시스(08~13년)    525   337   428
# 199               르노삼성SM5뉴SM5(신형)(10~12년)    367   329   521
# 534                    현대그랜저그랜저TG(05~08년)    299    14   898
# 182                         르노삼성QM3QM3(13~17년)    258   284   647
# 34                                  기아K3K3(12~15년)    313   310   550
# 62                   기아로체로체이노베이션(08~10년)    221   229   721
# 191                  르노삼성SM3SM3네오(14년~현재)    166   243   756
# 381                     쌍용티볼리티볼리(15~17년)    194   512   432
# 530                    현대그랜저그랜저HG(11~16년)    401   223   505
# 36                              기아K3더뉴K3(15~18년)    408   269   377
# 98                    기아오피러스뉴오피러스(06~09년)    304   218   442
# 88                 기아쏘렌토더뉴쏘렌토(17년~현재)    297   258   408
# 341     쉐보레(GM대우)토스카토스카프리미엄6(08~11년)    345    44   560
# 558                      현대쏘나타NF쏘나타(04~07년)    148   144   650
# 187                      르노삼성QM6QM6(16년~현재)    292   232   414
# 343             쉐보레(GM대우)트랙스트랙스(13~16년)    101   105   730
# 89                        기아쏘렌토쏘렌토(02~06년)    274   195   447
# 8                  BMW3시리즈3시리즈(G20)(19년~현재)    157   135   623
# 304       쉐보레(GM대우)라세티라세티프리미어(08~11년)    323   236   352
# 197             르노삼성SM5SM5뉴임프레션(07~10년)    256   253   397
# 83            기아스포티지스포티지더볼드(18년~현재)    318   181   395
# 258              벤츠E-클래스E-클래스W212(09~17년)    169   350   371
# 203                         르노삼성SM7SM7(04~08년)    327   109   440
# 504                          푸조20082008(13년~현재)    248   183   431
# 245           벤츠C-클래스C-클래스W205(14년~현재)     71   323   457
# 156  랜드로버레인지로버이보크레인지로버이보크(11...     74   266   498
# 93                            기아쏘울쏘울(08~13년)    194   234   392
# 546           현대스타렉스그랜드스타렉스(07~17년)     56   153   610
# 443                 지프랭글러랭글러(JK)(07~18년)    117   197   482
# 599                         현대코나코나(17년~현재)    183   157   450
# 439                        제네시스G70G70(17년~현재)    187   317   277
# 570                  현대아반떼더뉴아반떼(13~15년)    195   257   320
# 313        쉐보레(GM대우)말리부올뉴말리부(16~18년)    224   222   324
# 597                  현대제네시스제네시스DH(13~16년)     97   125   545
# 112                     기아카렌스카렌스II(02~06년)     26   155   585
# 338               쉐보레(GM대우)크루즈크루즈(11~14년)    203   238   324
# 195                         르노삼성SM5SM5(98~05년)     40    40   684
# 312             쉐보레(GM대우)말리부말리부(11~16년)    211   140   413
# 579                    현대아반떼아반떼XD(00~03년)     47   100   611
# 168                           렉서스ISIS250(05~13년)     21   214   523
# 204                   르노삼성SM7SM7NewArt(08~11년)    249   203   295
# 86                      기아쏘렌토뉴쏘렌토(06~09년)    188   179   380
# 40                        기아K5K5하이브리드(11~15년)    240   201   297
# 391                          아우디A6뉴A6(04년~현재)     47    47   642
# 14                 BMW6시리즈6시리즈(F12)(11년~현재)    214     3   518
# 119                기아프라이드올뉴프라이드(11~15년)    144   111   476
# 603            현대투스카니투스카니(신형)(06~08년)     70   102   551
# 100            기아오피러스오피러스프리미엄(09~11년)    243   184   286
# 54                              기아K9더뉴K9(14~18년)    190   159   354
# 516                               푸조607607(99~10년)    219   208   270
# 77                     기아스팅어스팅어(17년~현재)    191   210   288
# 37                          기아K3올뉴K3(18년~현재)    125   142   403
# 433                    재규어F-PACEF-PACE(16년~현재)    239    20   409
# 327           쉐보레(GM대우)올란도올란도(11~18년)    207   165   283
# 550                      현대싼타페싼타페(00~05년)     35    41   556
# 448               지프체로키그랜드체로키(93년~현재)    155   164   309
# 388                             아우디A4뉴A4(05~16년)    150    80   379
# 481                   포르쉐카이엔뉴카이엔(10~17년)    129   154   322
# 198                       르노삼성SM5뉴SM5(05~07년)    169   165   270
# 608                        현대투싼투싼ix(09~13년)    161   175   247
# 26                              BMWX5X5(E70)(07~13년)    110   188   275
# 401                            아우디S3S3(96년~현재)    136    50   383
# 196                  르노삼성SM5SM5노바(15년~현재)    181   150   234
# 104                기아카니발더뉴카니발(18년~현재)    176   166   215
# 598                현대제네시스제네시스쿠페(08~11년)    141   137   270
# 435                            재규어XFNewXF(11~15년)    186   131   230
# 360                         쌍용무쏘뉴무쏘(98~04년)      3    20   521
# 52                                  기아K9K9(12~14년)    143   135   253
# 94                          기아쏘울쏘울EV(14~19년)     39     1   491
# 103                     기아카니발뉴카니발(06~10년)    121   116   293
# 283                           볼보S60S60(00년~현재)    161    72   286
# 493                폭스바겐시로코시로코(08년~현재)     78   168   266
# 207                     르노삼성클리오(18년~현재)     63   109   338
# 170                      렉서스IS뉴IS250(13년~현재)    182   313     2
# 96                 기아쏘울쏘울부스터EV(19년~현재)     48   110   339
# 6                     BMW3시리즈3시리즈(E90)(05~13년)    136    40   316
# 260           벤츠E-클래스E-클래스W213(16년~현재)    251   128   111
# 563                현대쏘나타쏘나타뉴라이즈(17~19년)    151   128   207
# 38                                  기아K5K5(10~13년)    256    86   139
# 7                     BMW3시리즈3시리즈(F30)(12~18년)    108   131   229
# 591                    현대엑센트엑센트(94~97년)    127   146   194
# 309   쉐보레(GM대우)마티즈마티즈크리에이티브(09~11년)    151   107   187
# 386                          아우디A3뉴A3(03년~현재)     19   150   274
# 328           쉐보레(GM대우)윈스톰윈스톰(06~10년)    129   118   189
# 274          벤츠GLK-클래스GLK-클래스X206(09~15년)    122   100   214
# 19                              BMWM3M3(E90)(07~13년)      0     0   432
# 120             기아프라이드프라이드(신형)(05~11년)     99   106   222
# 291                            볼보XC70XC70(97~16년)      9     6   408
# 184                         르노삼성QM5QM5(07~11년)    110   105   203
# 246                       벤츠C-클래스W204(07~14년)    219     0   194
# 57                       기아레이더뉴레이(17년~현재)    110   145   155
# 202                   르노삼성SM7AllNewSM7(11~14년)    129   112   158
# 611           현대팰리세이드팰리세이드(18년~현재)     38   158   193
# 76                     기아스토닉스토닉(17년~현재)    108   108   171
# 532                 현대그랜저그랜저IG(16년~현재)    133   114   136
# 205                  르노삼성SM7SM7노바(14년~현재)    119   111   153
# 254                  벤츠CLS-클래스C257(18년~현재)      5   159   211
# 326           쉐보레(GM대우)알페온알페온(10~15년)    103   107   161
# 566          현대쏘나타쏘나타더브릴리언트(12~14년)    117   104   142
# 51                기아K7올뉴K7하이브리드(16년~현재)    126   101   134
# 73      기아봉고III미니버스봉고III미니버스(04~05년)    128   154    79
# 193                        르노삼성SM3뉴SM3(09~14년      0    90   269
# 273       벤츠GLE-클래스GLE-클래스W166(16년~현재)    225    30   100
# 276              벤츠M-클래스M-클래스W166(12~15년)     49    44   244
# 604                      현대투싼뉴투싼ix(13~15년)     88    85   163
# 53                             기아K9더K9(18년~현재)     90    81   159
# 422                       인피니티Q50Q50(14년~현재)     92    88   147
# 115                         기아포르테포르테(08~13년)     91    85   149
# 153  랜드로버레인지로버벨라레인지로버벨라(17녀...    132    81   106
# 255       벤츠CLS-클래스CLS-클래스C257(18년~현재)    119   128    68
# 44                      기아K5더뉴K52세대(18년~현재)    103    85   126
# 298          쉐보레(GM대우)다마스뉴다마스(08년~현재)     19   100   194
# 354          쌍용렉스턴렉스턴스포츠(18년~현재)     98   103   110
# 441                        제네시스G90G90(18년~현재)    121   111    77
# 262                       벤츠E-클래스W212(09~17년)     75     0   231
# 432                    재규어E-PACEE-PACE(18년~현재)     78    49   157
# 163                         렉서스ES뉴ES350(12~18년)      2   249    24
# 501            폭스바겐파사트더뉴파사트(11년~현재)     19   177    78
# 336    쉐보레(GM대우)크루즈어메이징뉴크루즈(15~17년)     81    87   101
# 614                    혼다CR-VCR-V5세대(17년~현재)     93   159    13
# 342      쉐보레(GM대우)트랙스더뉴트랙스(16년~현재)     68    62   132
# 590                현대에쿠스에쿠스(신형)(09~15년)    106    80    75
# 547    현대스타렉스더뉴그랜드스타렉스(17년~현재)     88    79    85
# 335             쉐보레(GM대우)캡티바캡티바(11~18년)     75    72   101
# 589                        현대에쿠스에쿠스(99~09년)     77    69   102
# 221                마세라티기블리기블리(13년~현재)    153    33    62
# 607                          현대투싼투싼(04~09년)     51    65   129
# 595                  현대제네시스제네스시DH(13~16년)     55    58   132
# 305                   쉐보레(GM대우)레조레조(00~07년)     56    27   159
# 244              벤츠C-클래스C-클래스W204(07~14년)    190    14    36
# 67                            기아모닝모닝(04~08년)     56    79   101
# 97                       기아쏘울올뉴쏘울(13~16년)     66    75    93
# 331        쉐보레(GM대우)임팔라임팔라(15년~현재)     68    64   101
# 491                   폭스바겐비틀뉴비틀(98~12년)      1   149    80
# 544                  현대벨로스터벨로스터(11~14년)    101     3   122
# 278              벤츠S-클래스S-클래스W221(05~13년)     86    73    65
# 257          벤츠CLS-클래스CLS-클래스W219(04~11년)      6   161    54
# 450                  지프체로키체로키(KL)(14년~현재)     57    40   117
# 116                      기아포르테포르테쿱(09~13년)     35    68   111
# 118                 기아프라이드더뉴프라이드(15~17년)     58    56   100
# 396                               아우디Q7Q7(05~15년)    152    21    40
# 280           벤츠S-클래스S-클래스W222(13년~현재)     30   159    22
# 557            현대쏘나타LF쏘나타하이브리드(14~17년)     55    56    89
# 162                        렉서스ES뉴ES300h(12~18년)     22    35   141
# 348              쌍용렉스턴G4렉스턴(17년~현재)     59    63    76
# 539          현대맥스크루즈더뉴맥스크루즈(15~19년)     66    68    63
# 185                     르노삼성QM5QM5네오(14~16년)     56    55    83
# 275              벤츠M-클래스M-클래스W164(05~11년)      8   175    10
# 272       벤츠GLC-클래스GLC-클래스X253(16년~현재)     30    28   134
# 306         쉐보레(GM대우)마티즈AllNew마티즈(05~09년)     39    65    88
# 186                       르노삼성QM5뉴QM5(11~14년)     55    50    87
# 24                              BMWX3X3(F25)(11~17년)     15   107    69
# 261              벤츠E-클래스E-클래스W213(76~85년)     42    35   114
# 538                       현대넥쏘넥쏘(18년~현재)    100    10    74
# 573                      현대아반떼아반떼(95~98년)     17    27   137
# 290                            볼보XC60XC60(09~17년)    112     8    60
# 337       쉐보레(GM대우)크루즈올뉴크루즈(17년~현재)     60    47    69
# 110                  기아카렌스올뉴카렌스(13~16년)     53    52    70
# 585                    현대아슬란아슬란(14~18년)     50    36    84
# 617                   혼다어코드올뉴어코드(08~17년)    153     6    11
# 256          벤츠CLS-클래스CLS-클래스W218(11~17년)     42    86    39
# 377           쌍용코란도더뉴코란도스포츠(16~18년)     22    62    80
# 11                    BMW5시리즈5시리즈(E60)(03~10년)      4     3   152
# 47                        기아K7K7하이브리드(13~16년)     42    45    62
# 35                               기아K3K3쿱(13~16년)     39    42    66
# 42                   기아K5K5하이브리드2세대(15~18년)     37    32    78
# 588        현대아이오닉아이오닉하이브리드(16~19년)     42    43    59
# 575                 현대아반떼아반떼AD(15년~18년)     51    49    42
# 452                       지프컴패스컴패스(07~17년)     27    45    69
# 580                    현대아반떼아반떼XD(03~06년)      0    26   114
# 157  랜드로버레인지로버이보크레인지로버이보크(11...     45    38    54
# 223      마세라티콰트로포르테콰트로포르테(63년~현재)    100    10    27
# 393                          아우디A8뉴A8(02년~현재)     49    42    41
# 218    링컨컨티넨탈컨티넨탈10세대(16년~현재)     97    15    19
# 594            현대제네시스더뉴제네시스쿠페(11~16년)     34    29    68
# 503                  폭스바겐폴로폴로(75년~현재)    113     1    16
# 28                              BMWX6X6(E71)(08~14년)     41    36    52
# 340               쉐보레(GM대우)토스카토스카(06~08년)     40    35    54
# 16                    BMW7시리즈7시리즈(F01)(08~15년)     45    37    45
# 192            르노삼성SM3SM3뉴제너레이션(05~11년)     40    35    51
# 41                   기아K5K5하이브리드2새대(15~18년)     58     0    68
# 390                               아우디A6A6(94~04년)     34    40    51
# 27                              BMWX5X5(F15)(13~18년)      8    16   101
# 478                          포르쉐911911(89년~현재)     37    23    64
# 414                            인피니티GG37(08~13년)     33    28    62
# 259           벤츠E-클래스E-클래스W212(09년~17년)    110     0    13
# 152  랜드로버레인지로버레인지로버4세대(13년~현재)     21    74    28
# 345               스마트포투포투쿠페3세대(14년~현재)     94     8    21
# 394                            아우디Q3Q3(11년~현재)     54    18    49
# 85                          기아쎄라토쎄라토(03~06년)     69     3    47
# 383              쌍용티볼리티볼리에어(16년~현재)     33    39    47
# 413                            인피니티GG35(03~08년)     35    33    50
# 389                            아우디A5A5(07년~현재)     71    11    33
# 447              지프레니게이드레니게이드(15년~현재)     28    29    57
# 613             현데싼타페싼타페더프라임(15~18년)    114     0     0
# 488                폭스바겐골프골프5세대(04~09년)    104     1     5
# 483                   포르쉐파나메라파나메라(09~16년)     21    28    60
# 497               폭스바겐티구안뉴티구안(11~16년)     74    14    19
# 150  랜드로버디스커버리스포츠디스커버리스포츠(15녀...     28    25    49
# 569                  현대아반떼뉴아반떼XD(03~06년)     30    22    50
# 45            기아K5더뉴K5하이브리드2세대(18년~현재)     29    27    44
# 583            현대아반떼아반떼하이브리드(09~13년)     29    26    45
# 33                                  기아(아시아)봉고3     44     0    53
# 606                        현대투싼투산ix(09~13년)     53     0    43
# 392                            아우디A7A7(10년~현재)     32    30    34
# 371                    쌍용체어맨체어맨W(08~11년)     67     8    20
# 395                            아우디Q5Q5(08년~현재)     33    30    32
# 217                        링컨MKZ뉴MKZ(10년~현재)     37    13    44
# 183                    르노삼성QM3뉴QM3(17년~현재)     24    21    49
# 418                            인피니티MM37(10~13년)     29    24    40
# 294                             삼성QM3QM3(13~17년)     66     0    26
# 99                      기아오피러스오피러스(03~06년)     25    23    42
# 126                  닛산알티마알티마(93년~현재)     27    25    38
# 373            쌍용코란도뉴스타일코란도(17~18년)     26    24    40
# 10                         BMW5시리즈5시리즈(72~03년)      1    85     2
# 243      벤츠B-클래스(MYB)B-클래스W246(12년~현재)      8    76     4
# 1                     BMW1시리즈1시리즈(E82)(04~13년)     82     0     6
# 379               쌍용코란도코란도스포츠(12~16년)     24    30    33
# 295                          삼성QM6QM6(16년~현재)     80     0     6
# 362                     쌍용무쏘무쏘스포츠(02~06년)      4    78     2
# 253       벤츠CLA-클래스CLA-클래스C117(14년~현재)     30    28    26
# 271       벤츠GLA-클래스GLA-클래스X156(14년~현재)     29    27    26
# 472          포드익스플로러익스플로러(91년~현재)     23    27    31
# 106                     기아카니발카니발II(01~05년)     19    25    37
# 301              쉐보레(GM대우)라보뉴라보(08년~현재)      7    36    37
# 535             현대그랜저그랜저뉴럭셔리(08~09년)     51    13    16
# 412                            인피니티GG25(11~13년)     20    16    42
# 571               현대아반떼더뉴아반떼(13년~15년)     23    25    29
# 132               닷지램픽업램픽업(81년~현재)     48     1    28
# 208              르노삼성클리오클리오(18년~현재)     18    18    40
# 380          쌍용코란도코란도투리스모(13년~현재)     32    29    15
# 521                       현대i30i30(PD)(16년~현재)     47    14    14
# 229                          미니쿠퍼쿠퍼(01년~현재)     16    24    35
# 171                           렉서스LSLS430(00~06년)     44     0    31
# 541                현대베라크루즈베라크루즈(06~15년)     23    20    31
# 241         벤츠B-클래스(MYB)B-클래스W245(05~11년)     54     0    20
# 442             지프-레니게이드레니게이드(15년~현재)     43     0    30
# 561                    현대쏘나타뉴EF쏘나타(01~06년)     16    18    38
# 592         현대엑센트엑센트(신형)(10년~현재)     14    44    13
# 138                    도요타시에나시에나(98년~현재)     24    20    26
# 92                        기아쏘울더뉴쏘울(16~19년)     18    22    29
# 417                            인피니티MM35(03~10년)     20    23    25
# 490             폭스바겐골프골프7세대(13년~현재)     20    19    29
# 517                         피아트500500C(09년~현재)      2     0    65
# 30                              BMWZ4Z4(E89)(09~16년)      0    42    25
# 231                         미니쿠퍼쿠퍼S(01년~현재)     13    18    35
# 148           랜드로버디스커버리디스커버리4(09~16년)     30    15    20
# 324          쉐보레(GM대우)아베오아베오세단(11~16년)     13    20    31
# 424                       인피니티Q70Q70(14년~현재)     17     7    39
# 32        BMW그란투리스모(GT)5시리즈GT(F07)(10~17년)     20    19    23
# 109                   기아카렌스더뉴카렌스(16~18년)     17    19    23
# 136                           도요타RAV4RAV4(94~18년)      0    58     0
# 350                   쌍용렉스턴렉스턴(01~03년)     16    13    29
# 284                              볼보S80S80(98~16년)     16    14    28
# 609                    현대트라제XG트라제XG(99~07년)     13    12    32
# 479                      포르쉐마칸마칸(14년~현재)     10    13    32
# 353                  쌍용렉스턴렉스턴W(12~17년)     18    16    19
# 189                   르노삼성SM3SM3Z.E(13년~현재)     19     8    26
# 18                           BMWM2M2(F87)(16년~현재)     45     3     4
# 601                      현대테라칸테라칸(01~06년)     14    19    18
# 239           벤츠A-클래스A-클래스W176(13년~현재)     17    17    17
# 319        쉐보레(GM대우)스파크더뉴스파크(18년~현재)     14    16    21
# 154  랜드로버레인지로버스포츠레인지로버스포츠(04...     15    12    23
# 60                              기아로체로체(05~07년)     16    11    23
# 559            현대쏘나타NF쏘나타트랜스폼(07~13년)     18    18    14
# 568                   현대쏠라티쏠라티(15년~현재)     16    18    15
# 325        쉐보레(GM대우)아베오아베오해치백(11~16년)     15    14    20
# 545           현대벨로스터벨로스터(JS)(18년~현재)     15    14    20
# 296                          삼성SM6SM6(16년~현재)      0     7    42
# 172                           렉서스LSLS460(06~17년)     35     5     9
# 117                  기아포르테포르테해치백(10~13년)     12     9    27
# 347                       시트로엥DS3DS3(09년~현재)     12     4    32
# 548                  현대스타렉스스타렉스(97~07년)     13    16    19
# 209                르노삼성트위지트위지(17년~현재)      2     7    38
# 315           쉐보레(GM대우)베리타스베리타스(08~10년)     15    12    19
# 364             쌍용액티언액티언스포츠(06~11년)     14    15    17
# 410                          인피니티FXFX35(03~13년)     15    12    19
# 308             쉐보레(GM대우)마티즈마티즈II(00~05년)      9    14    23
# 612                                         현대포터2     42     0     3
# 549             현대스타렉스스타렉스점보(97~07년)     13    16    16
# 307              쉐보레(GM대우)마티즈마티즈2(00~05년)     36     8     0
# 101                       기아옵티마옵티마(00~05년)     16     9    19
# 330      쉐보레(GM대우)이쿼녹스이쿼녹스(18년~현재)     15    10    18
# 84                        기아쎄라토뉴쎄라토(06~08년)     14    14    15
# 543              현대벨로스터더뉴벨로스터(15~18년)     16    16    10
# 127                        닛산쥬크쥬크(11년~현재)     11    10    21
# 292                            볼보XC90XC90(03~14년)     14    12    16
# 467                          포드F150F150(73년~현재)      9     9    23
# 421                       인피니티Q30Q30(16년~현재)     14     7    20
# 468                    포드머스탱머스탱(64년~현재)     11    12    17
# 74                          기아비스토비스토(99~04년)      7     6    27
# 225         미니컨트리맨쿠퍼D컨트리맨(11년~현재)     12     9    19
# 382              쌍용티볼리티볼리아머(17년~현재)     15    14    11
# 408                          인피니티EXEX35(08~13년)     11    12    16
# 525                              현대i40i40(11~15년)     16    17     5
# 233           미니클럽맨쿠퍼D클럽맨(09년~현재)      9     9    20
# 13                 BMW5시리즈5시리즈(G30)(17년~현재)      9    18     9
# 482                     포르쉐카이엔카이엔(02~10년)     10    10    16
# 210                          링컨MKCMKC(14년~현재)     15    11     9
# 480                     포르쉐박스터박스터(96~16년)      5     6    24
# 533       현대그랜저그랜저IG하이브리드(17년~현재)     12     9    14
# 4     BMW2시리즈2시리즈액티브투어러(F45)(15년~현재)      1    32     1
# 78                    기아스펙트라스펙트라(00~04년)     15     8    11
# 449                         지프체로키체로키(84~13년)      7     4    22
# 476                   포르쉐718718박스터(16년~현재)      5     7    21
# 602                    현대투스카니투스카니(01~06년)      4    10    19
# 139                       도요타캠리뉴캠리(12~17년)     12     8    13
# 524                          현대i30더뉴i30(15~16년)     10    10    13
# 527                       현대i40더뉴i40(15년~현재)     12    13     7
# 339              쉐보레(GM대우)크루즈크루즈5(11~14년)      5    12    15
# 61                     기아로체로체어드밴스(07~08년)     12    12     8
# 286                           볼보V40V40(95년~현재)      7     7    17
# 302                   쉐보레(GM대우)라보라보(91~06년)      1    13    17
# 429                     인피니티QX70QX70(14년~현재)      6     9    16
# 428                     인피니티QX60QX60(14년~현재)      8     7    16
# 407                             아우디TT뉴TT(06~14년)      9    11    11
# 351                  쌍용렉스턴렉스턴2(06~08년)      0    30     0
# 378                    쌍용코란도코란도C(11~13년)     10    10    10
# 425                            인피니티QQ45(90~08년)     10    10    10
# 537             현대그랜저더럭셔리그랜저(09~11년)     15     9     5
# 155  랜드로버레인지로버스포츠레인지로버스포츠2세...      8     7    14
# 227          미니컨트리맨쿠퍼컨트리맨(11년~현재)      8     9    12
# 228      미니쿠퍼컨버터블쿠퍼컨버터블(01년~현재)      4     7    17
# 486                      폭스바겐CC뉴CC(12년~현재)      9    10     8
# 446                 지프랭글러랭글러(YJ)(87~95년)      5     4    18
# 540              현대맥스크루즈맥스크루즈(13~15년)     10     7    10
# 174                         렉서스LSLS600hL(06~17년)      8    12     7
# 166                      렉서스GS뉴GS350(12년~현재)      8     8    10
# 317     쉐보레(GM대우)스테이츠맨스테이츠맨(05~07년)     11     5    10
# 293                    볼보XC90XC902세대(16년~현재)      8     7    10
# 444              지프랭글러랭글러(JL)(18년~현재)      8     3    13
# 303               쉐보레(GM대우)라세티라세티(02~09년)      7     6    11
# 356               쌍용렉스턴슈퍼렉스턴(08~12년)     10    10     4
# 242      벤츠B-클래스(MYB)B-클래스W245(05년~11년)      7     7    10
# 376                  쌍용코란도뉴코란도C(13~17년)      5     8    11
# 137                        도요타RAV4RAV4(94년~현재)      7     6    10
# 111                       기아카렌스카렌스(99~02년)      9     9     5
# 363                   쌍용액티언액티언(05~11년)      8     9     5
# 124             닛산맥시마맥시마(A36)(15년~현재)      5     6    11
# 282                              볼보C30C30(06~13년)      3     4    15
# 565   현대쏘나타쏘나타뉴라이즈하이브리드(17년~현재)      8     8     6
# 431                          인피니티QXQX56(04~13년)      8     7     7
# 461                      크라이슬러300C300C(04~10년)      4     5    13
# 385                            아우디A3A3(03년~현재)      9     7     5
# 23                              BMWX1X1(E84)(10~15년)      7     5     9
# 236            미니클럽맨쿠퍼클럽맨(07년~현재)      7     5     9
# 188                         르노삼성SM3SM3(02~05년)      6     2    13
# 564      현대쏘나타쏘나타뉴라이즈하이브리드(17~19년)      5    10     5
# 520                              현대i30i30(07~11년)      5     6     9
# 586       현대아이오닉아이오닉일렉트릭(16~19년)      4     6    10
# 411                          인피니티FXFX50(09~13년)      4     4    12
# 496            폭스바겐투아렉뉴투아렉(10년~현재)      6     9     5
# 31     BMW그란투리스모(GT)3시리즈GT(F34)(13년~현재)      7     9     4
# 56                         기아니로니로EV(18년~현재)      5     4    11
# 222                마세라티르반떼르반떼(16년~현재)      4     9     7
# 211                             링컨MKSMKS(08~12년)      5     6     9
# 230                         미니쿠퍼쿠퍼D(07년~현재)      5     4    10
# 129                        닛산큐브큐브(98년~현재)      5     4    10
# 374           쌍용코란도뉴스타일코란도C(17~18년)     19     0     0
# 355       쌍용렉스턴렉스턴스포츠칸(19년~현재)      4     8     7
# 161                           렉서스ESES350(06~12년)      7     5     7
# 460    캐딜락에스컬레이드에스컬레이드(99년~현재)      5     4     9
# 555                      현대쏘나타EF쏘나타(98~01년)      4     4     9
# 453               지프컴패스컴패스2세대(18년~현재)      3     4    10
# 2                  BMW1시리즈1시리즈(F20)(12년~현재)      4     5     7
# 316          쉐보레(GM대우)볼트EV볼트EV(17년~현재)      5     3     8
# 226        미니컨트리맨쿠퍼SD컨트리맨(11년~현재)      5     4     7
# 158             랜드로버프리랜더프리랜더2(06~14년)      5     3     8
# 615                         혼다CR-VNewCR-V(11~16년)      4     5     7
# 582                  현대아반떼아반떼쿠페(13~15년)      7     5     3
# 462               크라이슬러300C더뉴300C(12년~현재)      4     4     7
# 178                          렉서스RXRX450h(09~15년)      5     5     5
# 463                 크라이슬러300C올뉴300C(11~12년)      5     4     6
# 528                 현대i40더뉴i40살룬(15년~현재)      5     5     5
# 508                             푸조30083008(09~16년)      5     4     6
# 451                       지프커맨더커맨더(06~10년)      6     4     5
# 59                          기아레토나레토나(98~03년)      2     5     7
# 459                           캐딜락SRXSRX(04~09년)      4     2     8
# 219                     링컨타운카타운카(81~11년)      3     4     7
# 445                 지프랭글러랭글러(TJ)(96~06년)      1     3    10
# 140                         도요타캠리캠리(86~11년)      3     3     7
# 269      벤츠G-클래스(G바겐)G-클래스W463(79~19년)      4     1     8
# 213                             링컨MKXMKX(06~10년)      3     2     8
# 216                             링컨MKZMKZ(05~09년)      6     2     5
# 498                 폭스바겐티구안티구안(07~11년)      3     3     7
# 281            벤츠SLK-클래스뉴SLK-클래스(04~16년)      3     3     7
# 474                         포드토러스토러스(86~09년)      4     3     6
# 214                        링컨MKXMKX2세대(15~18년)      5     4     4
# 300             쉐보레(GM대우)다마스다마스II(03~07년)      1     7     5
# 175                       렉서스NXNX300h(14년~현재)      3     3     6
# 332            쉐보레(GM대우)젠트라젠트라X(07~11년)      4     3     5
# 329      쉐보레(GM대우)윈스톰윈스톰맥스(08~10년)      3     3     6
# 177                           렉서스RXRX350(97~15년)      4     2     6
# 232                        미니쿠퍼쿠퍼SD(12년~현재)      3     2     7
# 349                 쌍용렉스턴뉴렉스턴(03~06년)      4     3     5
# 64                              기아리오리오(99~05년)      5     2     5
# 322   쉐보레(GM대우)아베오더뉴아베오세단(16년~현재)      3     4     5
# 125                       닛산무라노무라노(02~14년)      3     3     6
# 473                    포드토러스뉴토러스(09년~현재)      5     3     3
# 159                   렉서스CT200hCT200h(10년~현재)      4     1     6
# 514                               푸조508508(11~18년)      4     3     4
# 145           도요타프리우스프리우스4세대(16년~현재)      3     4     4
# 128           닛산캐시카이캐시카이2세대(14년~현재)      2     2     7
# 492                폭스바겐비틀더비틀(12년~현재)      3     3     5
# 500                 폭스바겐파사트뉴파사트(05~11년)      2     5     3
# 457                   캐딜락CTSCTS3세대(14년~현재)      4     2     4
# 334               쉐보레(GM대우)카마로카마로(11~15년)      3     3     4
# 455                        캐딜락ATSATS(13년~현재)      4     3     3
# 375                   쌍용코란도뉴코란도(96~05년)      2     3     5
# 384                            아우디A1A1(10년~현재)      5     3     2
# 206                르노삼성마스터마스터(18년~현재)      4     2     4
# 419                            인피니티MM45(03~10년)      2     2     6
# 526                        현대i40i40살룬(12~15년)      4     5     1
# 484           포르쉐파나메라파나메라(971)(17년~현재)      2     2     6
# 506                             푸조207207CC(06~13년)      1     2     6
# 415                          인피니티JXJX35(12~13년)      3     3     3
# 17                                BMWi8i8(14년~현재)      2     1     6
# 114                         기아타우너타우너(92~02년)      1     2     6
# 366                   쌍용체어맨뉴체어맨(03~08년)      2     3     4
# 372                   쌍용카이런뉴카이런(07~11년)      3     5     1
# 600              현대코나코나일렉트릭(18년~현재)      1     3     4
# 287              볼보V40V40크로스컨트리(13년~현재)      2     2     4
# 135                           도요타MR-2MR-2(84~07년)      1     1     6
# 141                도요타캠리캠리(XV70)(17년~현재)      3     2     3
# 277                  벤츠S-클래스S-클래스(93~06년)      0     5     3
# 359               쌍용로디우스로디우스유로(12~13년)      2     2     4
# 365                   쌍용이스타나이스타나(95~03년)      1     3     4
# 494                  폭스바겐제타뉴제타(11년~현재)      3     3     2
# 215                           링컨MKX뉴MKX(10~15년)      3     2     3
# 212                           링컨MKS뉴MKS(12~16년)      3     2     3
# 536                  현대그랜저뉴그랜저XG(02~05년)      3     4     1
# 368                  쌍용체어맨뉴체어맨W(11~17년)      2     1     5
# 173                          렉서스LSLS460L(06~17년)      3     4     1
# 587    현대아이오닉아이오닉일렉트릭(16년~현재)      1     3     4
# 397                        아우디Q7Q7(4M)(16년~현재)      3     2     3
# 399                          아우디RS5RS5(10년~현재)      4     2     2
# 25                              BMWX4X4(F26)(14~18년)      2     0     6
# 510                               푸조308308(07~14년)      1     2     5
# 507                            푸조208208(13년~현재)      2     3     3
# 502                   폭스바겐파사트파사트(73~05년)      2     1     4
# 529                     현대갤로퍼갤로퍼2(97~03년)      3     2     2
# 489                폭스바겐골프골프6세대(08~14년)      4     2     1
# 505                             푸조206206CC(00~08년)      1     1     5
# 618               혼다오딧세이오딧세이(95년~현재)      1     2     4
# 224                 미니로드스터쿠퍼로드스터(12~15년)      2     2     3
# 314           쉐보레(GM대우)매그너스매그너스(99~06년)      1     2     4
# 352                 쌍용렉스턴렉스턴II(06~08년)      2     3     2
# 369                    쌍용체어맨체어맨H(08~11년)      2     1     4
# 370          쌍용체어맨체어맨H뉴클래식(11~14년)      3     3     1
# 387                        아우디A4A4(B9)(16년~현재)      2     3     2
# 423                 인피니티Q60Q60(CV37)(18년~현재)      1     2     4
# 456                        캐딜락CT6CT6(16년~현재)      1     2     4
# 357                 쌍용로디우스뉴로디우스(07~12년)      1     3     3
# 416                           인피니티MM30d(10~13년)      2     3     2
# 409                         인피니티FXFX30d(09~13년)      2     2     3
# 169                        렉서스IS뉴IS200t(15~17년)      2     2     3
# 5                          BMW3시리즈3시리즈(75~06년)      3     2     2
# 268            벤츠E-클래스뉴E-클래스쿠페(09~17년)      2     3     2
# 151          랜드로버레인지로버레인지로버(70~12년)      1     1     5
# 146               도요타프리우스프리우스V(12년~현재)      1     2     3
# 220    마세라티그란투리스모그란투리스모(07년~현재)      1     2     3
# 420                            인피니티MM56(10~13년)      1     2     3
# 143                  도요타툰드라툰드라(00년~현재)      1     2     3
# 398                        아우디R8R8(4S)(16년~현재)      1     1     4
# 144                   도요타프리우스프리우스(97~15년)      0     2     4
# 279           벤츠S-클래스S-클래스W221(13년~현재)      1     2     3
# 403                             아우디SQ5SQ5(13~17년)      1     1     4
# 344                   쉐보레(GM대우)티코티코(91~01년)      1     2     3
# 113                     기아콩코드뉴콩코드(91~95년)      0     3     3
# 22                              BMWM5M5(F10)(12~17년)      1     2     3
# 311      쉐보레(GM대우)말리부더뉴말리부(18년~현재)      2     2     2
# 21                           BMWM4M4(F82)(14년~현재)      0     0     6
# 299               쉐보레(GM대우)다마스다마스(91~03년)      0     2     4
# 252            벤츠CL-클래스CL-클래스C216(07-13년)      1     1     4
# 9                  BMW4시리즈4시리즈(F32)(13년~현재)      0     2     4
# 471  포드익스플로러스포츠트랙익스플로러스포츠ᄐ...      1     1     4
# 288                 볼보V60V60크로스컨트리(15~18년)      1     1     4
# 542                현대베르나베르나(신형)(05~09년)      1     2     2
# 333          쉐보레(GM대우)카마로올뉴카마로(16~18년)      2     1     2
# 400                          아우디RS6RS6(02년~현재)      2     0     3
# 147         도요타프리우스프리우스프라임(17년~현재)      0     3     2
# 430                     인피니티QX80QX80(14년~현재)      3     1     1
# 513                               푸조407407(04~10년)      2     1     2
# 15                    BMW7시리즈7시리즈(E65)(02~08년)      1     1     3
# 20                           BMWM3M3(F80)(14년~현재)      1     2     2
# 63                        기아록스타록스타(90~93년)      0     1     4
# 434                            재규어XEXE(15년~현재)      2     2     1
# 285                           볼보S90S90(16년~현재)      2     1     2
# 593              현대엘란트라뉴엘란트라(93~95년)      1     1     3
# 134                   도요타FJ크루져FJ크루져(06~14년)      1     3     0
# 238                 벤츠A-클래스A-클래스W168(97~04)      1     2     1
# 3                  BMW2시리즈2시리즈(F22)(13년~현재)      1     2     1
# 616               혼다어코드어코드10세대(18년~현재)      1     1     2
# 160                           렉서스ESES330(01~06년)      1     1     2
# 149        랜드로버디스커버리디스커버리5(17년~현재)      1     1     2
# 240                       벤츠AMGGTAMGGT(14년~현재)      2     1     1
# 610                      현대티뷰론티뷰론(96~01년)      2     0     2
# 270            벤츠GL-클래스GL-클래스X164(06~12년)      1     1     2
# 237          미쯔비시아웃랜더아웃랜더(01년~현재)      1     1     2
# 176                           렉서스RXRX330(03~09년)      2     0     2
# 75                         기아세피아세피아2(97~01년)      1     1     2
# 95                   기아쏘울쏘울부스터(19년~현재)      1     2     1
# 584                 현대아반떼올뉴아반떼(98~00년)      1     1     2
# 121                           닛산350Z350Z(03~09년)      1     2     1
# 122                        닛산370Z370Z(09년~현재)      2     2     0
# 130     닛산패스파인더패스파인더4세대(13년~현재)      1     1     2
# 180                           렉서스SCSC430(01~10년)      0     2     2
# 165                        렉서스GS뉴GS200t(16~17년)      0     1     3
# 487                폭스바겐골프골프4세대(97~04년)      1     2     1
# 485                           폭스바겐CCCC(08~12년)      1     1     2
# 346            스즈키알토라팡알토라팡(02년~현재)      1     2     1
# 475                        포드퓨전퓨전(07년~현재)      2     1     1
# 495                       폭스바겐제타제타(79~11년)      2     0     2
# 469               포드몬데오몬데오4세대(15년~현재)      1     1     2
# 465              크라이슬러세브링뉴세브링(07~10년)      0     1     3
# 464  크라이슬러그랜드보이저그랜드보이저(88년~혀...      1     1     2
# 436                               재규어XFXF(08~11년)      1     0     3
# 427                        인피니티QX60QX56(14~현재)      1     2     1
# 426                        인피니티QX50QX50(14~17년)      1     2     1
# 522                      현대i30i30(신형)(11~15년)      1     1     2
# 523                            현대i30i30cw(08~11년)      2     2     0
# 404                          아우디SQ5SQ5(13년~현재)      2     2     0
# 531          현대그랜저그랜저HG하이브리드(13~17년)      1     1     2
# 367                   쌍용체어맨뉴체어맨(11~17년)      2     2     0
# 358                   쌍용로디우스로디우스(04~07년)      1     2     1
# 405                        아우디TTTT(8S)(14년~현재)      1     1     2
# 297                     쉐보레(GM대우)G2XG2X(07~08년)      1     0     3
# 310       쉐보레(GM대우)마티즈마티즈클래식(09~11년)      1     1     2
# 234          미니클럽맨쿠퍼SD클럽맨(13년~현재)      1     1     1
# 406                               아우디TTTT(98~06년)      1     1     1
# 477                   포르쉐718718카이맨(16년~현재)      0     1     2
# 470              포드이스케이프이스케이프(01년~현재)      0     1     2
# 466                           페라리F430F430(04~09년)      1     1     1
# 499         폭스바겐티구안티구안2세대(18년~현재)      1     1     1
# 264            벤츠E-클래스W212(09~17년)카브리올레      0     1     2
# 72                          기아베스타베스타(86~97년)      1     1     1
# 437                           재규어XJ-6XJ-6(68~07년)      1     1     1
# 123                        닛산GT-RGT-R(07년~현재)      1     0     2
# 133                               도요타bBbB(00~16년)      1     0     2
# 515                             푸조508508SW(11~18년)      2     0     1
# 518                        피아트500X500X(16년~현재)      0     1     2
# 0                               BMW1M1M(E82)(11~12년)      1     2     0
# 289                              볼보V70V70(97~12년)      0     0     3
# 164                           렉서스GSGS300(91~12년)      1     0     2
# 179                  렉서스RXRX450h4세대(16년~현재)      1     0     2
# 581      현대아반떼아반떼더뉴아반떼AD(18년~현재)      1     2     0
# 519                               험머H3H3T(09~10년)      0     0     2
# 511                       푸조3083082세대(14년~현재)      0     0     2
# 29                              BMWZ4Z4(E85)(02~08년)      0     0     2
# 458                           캐딜락DTSDTS(06~11년)      1     0     1
# 321               쉐보레(GM대우)씨에로씨에로(94~96년)      0     0     2
# 509                               푸조307307(01~09년)      0     1     1
# 167                     렉서스GS뉴GS450h(12년~현재)      0     0     2
# 142                  도요타코롤라코롤라(66년~현재)      0     1     1
# 131                        닷지다코타다코타(87~11년)      0     1     1
# 402                            아우디S7S7(12년~현재)      0     1     0
# 512                             푸조308308SW(07~14년)      0     1     0
# 361                           쌍용무쏘무쏘(93~98년)      0     0     0
# 323  쉐보레(GM대우)아베오더뉴아베오해치백(16년~혀...      0     0     0
# 267                벤츠E-클래스W213(16년~현재)쿠페      0     0     0
# 266                    벤츠E-클래스W213(16년~현재)      0     0     0
# 190                  르노삼성SM3SM3Z.E.(13년~현재)      0     0     0
# 265                   벤츠E-클래스W212(09~17년)쿠페      0     0     0
# 181                       렉서스UXUX250h(19년~현재)      0     0     0
# 263                    벤츠E-클래스W212(09~17년)AMG      0     0     0
# 578                 현대아반떼아반떼MD(10년~13년)      0     0     0
# 251                벤츠C-클래스W205(14년~현재)쿠페      0     0     0
# 250      벤츠C-클래스W205(14년~현재)AMG카브레올레      0     0     0
# 235           미니클럽맨쿠퍼S클럽맨(07년~현재)      0     0     0
# 249                 벤츠C-클래스W205(14년~현재)AMG      0     0     0
# 247                벤츠C-클래스W204(07~14년)AMG쿠페      0     0     0
# 248                    벤츠C-클래스W205(14년~현재)      0     0     0
# 454                    캐딜락ATS-VATS-V(16년~현재)      0     0     0
#
#      front_hflip  back_hflip  side_hflip  mix_hflip  total  totalWithAug  \
# 58             0           0           0          0   5081          5081
# ...
# 276       352      357      157
# 604       313      316      238
# 53        311      320      242
# 422       309      313      254
# 115       310      316      252
# 153       269      320      295
# 255       282      273      333
# 44        298      316      275
# 298       382      301      207
# 354       303      298      291
# 441       280      290      324
# 262       326      401      170
# 432       323      352      244
# 163       399      152      377
# 501       382      224      323
# 336       320      314      300
# 614       308      242      388
# 342       333      339      269
# 590       295      321      326
# 547       313      322      316
# 335       326      329      300
# 589       324      332      299
# 221       248      368      339
# 607       350      336      272
# 595       346      343      269
# 305       345      374      242
# 244       211      387      365
# 67        345      322      300
# 97        335      326      308
# 331       333      337      300
# 491       400      252      321
# 544       300      398      279
# 278       315      328      336
# 257       395      240      347
# 450       344      361      284
# 116       366      333      290
# 118       343      345      301
# 396       249      380      361
# 280       371      242      379
# 557       346      345      312
# 162       379      366      260
# 348       342      338      325
# 539       335      333      338
# 185       345      346      318
# 275       393      226      391
# 272       371      373      267
# 306       362      336      313
# 186       346      351      314
# 24        386      294      332
# 261       359      366      287
# 538       301      391      327
# 573       384      374      264
# 290       289      393      341
# 337       341      354      332
# 110       348      349      331
# 585       351      365      317
# 617       248      395      390
# 256       359      315      362
# 377       379      339      321
# 11        397      398      249
# 47        359      356      339
# 35        362      359      335
# 42        364      369      323
# 588       359      358      342
# 575       350      352      359
# 452       374      356      332
# 580       401      375      287
# 157       356      363      347
# 223       301      391      374
# 393       352      359      360
# 218       304      386      382
# 594       367      372      333
# 503       288      400      385
# 28        360      365      349
# 340       361      366      347
# 16        356      364      356
# 192       361      366      350
# 41        343      401      333
# 390       367      361      350
# 27        393      385      300
# 478       364      378      337
# 414       368      373      339
# 259       291      401      388
# 152       380      327      373
# 345       307      393      380
# 394       347      383      352
# 85        332      398      354
# 383       368      362      354
# 413       366      368      351
# 389       330      390      368
# 447       373      372      344
# 613       287      401      401
# 488       297      400      396
# 483       380      373      341
# 497       327      387      382
# 150       373      376      352
# 569       371      379      351
# 45        372      374      357
# 583       372      375      356
# 33        357      401      348
# 606       348      401      358
# 392       369      371      367
# 371       334      393      381
# 395       368      371      369
# 217       364      388      357
# 183       377      380      352
# 418       372      377      361
# 294       335      401      375
# 99        376      378      359
# 126       374      376      363
# 373       375      377      361
# 10        400      316      399
# 243       393      325      397
# 1         319      401      395
# 379       377      371      368
# 295       321      401      395
# 362       397      323      399
# 253       371      373      375
# 271       372      374      375
# 472       378      374      370
# 106       382      376      364
# 301       394      365      364
# 535       350      388      385
# 412       381      385      359
# 571       378      376      372
# 132       353      400      373
# 208       383      383      361
# 380       369      372      386
# 521       354      387      387
# 229       385      377      366
# 171       357      401      370
# 541       378      381      370
# 241       347      401      381
# 442       358      401      371
# 561       385      383      363
# 592       387      357      388
# 138       377      381      375
# 92        383      379      372
# 417       381      378      376
# 490       381      382      372
# 517       399      401      336
# 30        401      359      376
# 231       388      383      366
# 148       371      386      381
# 324       388      381      370
# 424       384      394      362
# 32        381      382      378
# 109       384      382      378
# 136       401      343      401
# 350       385      388      372
# 284       385      387      373
# 609       388      389      369
# 479       391      388      369
# 353       383      385      382
# 189       382      393      375
# 18        356      398      397
# 601       387      382      383
# 239       384      384      384
# 319       387      385      380
# 154       386      389      378
# 60        385      390      378
# 559       383      383      387
# 568       385      383      386
# 325       386      387      381
# 545       386      387      381
# 296       401      394      359
# 172       366      396      392
# 117       389      392      374
# 347       389      397      369
# 548       388      385      382
# 209       399      394      363
# 315       386      389      382
# 364       387      386      384
# 410       386      389      382
# 308       392      387      378
# 612       359      401      398
# 549       388      385      385
# 307       365      393      401
# 101       385      392      382
# 330       386      391      383
# 84        387      387      386
# 543       385      385      391
# 127       390      391      380
# 292       387      389      385
# 467       392      392      378
# 421       387      394      381
# 468       390      389      384
# 74        394      395      374
# 225       389      392      382
# 382       386      387      390
# 408       390      389      385
# 525       385      384      396
# 233       392      392      381
# 13        392      383      392
# 482       391      391      385
# 210       386      390      392
# 480       396      395      377
# 533       389      392      387
# 4         400      369      400
# 78        386      393      390
# 449       394      397      379
# 476       396      394      380
# 602       397      391      382
# 139       389      393      388
# 524       391      391      388
# 527       389      388      394
# 339       396      389      386
# 61        389      389      393
# 286       394      394      384
# 302       400      388      384
# 429       395      392      385
# 428       393      394      385
# 407       392      390      390
# 351       401      371      401
# 378       391      391      391
# 425       391      391      391
# 537       386      392      396
# 155       393      394      387
# 227       393      392      389
# 228       397      394      384
# 486       392      391      393
# 446       396      397      383
# 540       391      394      391
# 174       393      389      394
# 166       393      393      391
# 317       390      396      391
# 293       393      394      391
# 444       393      398      388
# 303       394      395      390
# 356       391      391      397
# 242       394      394      391
# 376       396      393      390
# 137       394      395      391
# 111       392      392      396
# 363       393      392      396
# 124       396      395      390
# 282       398      397      386
# 565       393      393      395
# 431       393      394      394
# 461       397      396      388
# 385       392      394      396
# 23        394      396      392
# 236       394      396      392
# 188       395      399      388
# 564       396      391      396
# 520       396      395      392
# 586       397      395      391
# 411       397      397      389
# 496       395      392      396
# 31        394      392      397
# 56        396      397      390
# 222       397      392      394
# 211       396      395      392
# 230       396      397      391
# 129       396      397      391
# 374       382      401      401
# 355       397      393      394
# 161       394      396      394
# 460       396      397      392
# 555       397      397      392
# 453       398      397      391
# 2         397      396      394
# 316       396      398      393
# 226       396      397      394
# 158       396      398      393
# 615       397      396      394
# 582       394      396      398
# 462       397      397      394
# 178       396      396      396
# 463       396      397      395
# 528       396      396      396
# 508       396      397      395
# 451       395      397      396
# 59        399      396      394
# 459       397      399      393
# 219       398      397      394
# 445       400      398      391
# 140       398      398      394
# 269       397      400      393
# 213       398      399      393
# 216       395      399      396
# 498       398      398      394
# 281       398      398      394
# 474       397      398      395
# 214       396      397      397
# 300       400      394      396
# 175       398      398      395
# 332       397      398      396
# 329       398      398      395
# 177       397      399      395
# 232       398      399      394
# 349       397      398      396
# 64        396      399      396
# 322       398      397      396
# 125       398      398      395
# 473       396      398      398
# 159       397      400      395
# 514       397      398      397
# 145       398      397      397
# 128       399      399      394
# 492       398      398      396
# 500       399      396      398
# 457       397      399      397
# 334       398      398      397
# 455       397      398      398
# 375       399      398      396
# 384       396      398      399
# 206       397      399      397
# 419       399      399      395
# 526       397      396      400
# 484       399      399      395
# 506       400      399      395
# 415       398      398      398
# 17        399      400      395
# 114       400      399      395
# 366       399      398      397
# 372       398      396      400
# 600       400      398      397
# 287       399      399      397
# 135       400      400      395
# 141       398      399      398
# 277       401      396      398
# 359       399      399      397
# 365       400      398      397
# 494       398      398      399
# 215       398      399      398
# 212       398      399      398
# 536       398      397      400
# 368       399      400      396
# 173       398      397      400
# 587       400      398      397
# 397       398      399      398
# 399       397      399      399
# 25        399      401      395
# 510       400      399      396
# 507       399      398      398
# 502       399      400      397
# 529       398      399      399
# 489       397      399      400
# 505       400      400      396
# 618       400      399      397
# 224       399      399      398
# 314       400      399      397
# 352       399      398      399
# 369       399      400      397
# 370       398      398      400
# 387       399      398      399
# 423       400      399      397
# 456       400      399      397
# 357       400      398      398
# 416       399      398      399
# 409       399      399      398
# 169       399      399      398
# 5         398      399      399
# 268       399      398      399
# 151       400      400      396
# 146       400      399      398
# 220       400      399      398
# 420       400      399      398
# 143       400      399      398
# 398       400      400      397
# 144       401      399      397
# 279       400      399      398
# 403       400      400      397
# 344       400      399      398
# 113       401      398      398
# 22        400      399      398
# 311       399      399      399
# 21        401      401      395
# 299       401      399      397
# 252       400      400      397
# 9         401      399      397
# 471       400      400      397
# 288       400      400      397
# 542       400      399      399
# 333       399      400      399
# 400       399      401      398
# 147       401      398      399
# 430       398      400      400
# 513       399      400      399
# 15        400      400      398
# 20        400      399      399
# 63        401      400      397
# 434       399      399      400
# 285       399      400      399
# 593       400      400      398
# 134       400      398      401
# 238       400      399      400
# 3         400      399      400
# 616       400      400      399
# 160       400      400      399
# 149       400      400      399
# 240       399      400      400
# 610       399      401      399
# 270       400      400      399
# 237       400      400      399
# 176       399      401      399
# 75        400      400      399
# 95        400      399      400
# 584       400      400      399
# 121       400      399      400
# 122       399      399      401
# 130       400      400      399
# 180       401      399      399
# 165       401      400      398
# 487       400      399      400
# 485       400      400      399
# 346       400      399      400
# 475       399      400      400
# 495       399      401      399
# 469       400      400      399
# 465       401      400      398
# 464       400      400      399
# 436       400      401      398
# 427       400      399      400
# 426       400      399      400
# 522       400      400      399
# 523       399      399      401
# 404       399      399      401
# 531       400      400      399
# 367       399      399      401
# 358       400      399      400
# 405       400      400      399
# 297       400      401      398
# 310       400      400      399
# 234       400      400      400
# 406       400      400      400
# 477       401      400      399
# 470       401      400      399
# 466       400      400      400
# 499       400      400      400
# 264       401      400      399
# 72        400      400      400
# 437       400      400      400
# 123       400      401      399
# 133       400      401      399
# 515       399      401      400
# 518       401      400      399
# 0         400      399      401
# 289       401      401      398
# 164       400      401      399
# 179       400      401      399
# 581       400      399      401
# 519       401      401      399
# 511       401      401      399
# 29        401      401      399
# 458       400      401      400
# 321       401      401      399
# 509       401      400      400
# 167       401      401      399
# 142       401      400      400
# 131       401      400      400
# 402       401      400      401
# 512       401      400      401
# 361       401      401      401
# 323       401      401      401
# 267       401      401      401
# 266       401      401      401
# 190       401      401      401
# 265       401      401      401
# 181       401      401      401
# 263       401      401      401
# 578       401      401      401
# 251       401      401      401
# 250       401      401      401
# 235       401      401      401
# 249       401      401      401
# 247       401      401      401
# 248       401      401      401
# 454       401      401      401

# %%
def save_to_gray(src: str, dst: str):
    try:
        image = cv2.imread(src)
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        cv2.imwrite(dst, gray)
    except Exception as e:
        print(e)

DEST = '/Volumes/TriveStorage/code/trive-image-recognition/complete_manual/cars_refined'

if not os.path.exists(DEST):
    os.mkdir(DEST)

TEST_PATH = os.path.join(DEST, 'test')

if not os.path.exists(TEST_PATH):
    os.mkdir(TEST_PATH)

TRAIN_PATH = os.path.join(DEST, 'train')

if not os.path.exists(TRAIN_PATH):
    os.mkdir(TRAIN_PATH)

augmentations = [
    'hflip',
#     'smartcrop',
#     'saltpepper0d01',
#     'saltpepper0d02',
#     'saltpepper0d03',
#     'saltpepper0d04',
#     'saltpepper0d05',
#     'saltpepper0d06',
#     'saltpepper0d07',
#     'saltpepper0d08',
#     'saltpepper0d09',
#     'saltpepper0d10',
#     'translatex25y0',
#     'translatex0y25',
#     'translatex0ym25',
#     'translatexm25y0',
#     'gaussian',
]

front_augs = [f'front_{x}' for x in augmentations]
back_augs = [f'back_{x}' for x in augmentations]
side_augs = [f'side_{x}' for x in augmentations] + [f'mix_{x}' for x in augmentations]

def random_string(stringLength=10):
    """Generate a random string of fixed length """
    letters = string.ascii_lowercase
    return ''.join(random.choice(letters) for i in range(stringLength))

limit = sys.maxsize
for index, row in top_100.iterrows():
    print(row['name'])
    vehicle_test_path = os.path.join(TEST_PATH, row['name'])
    if not os.path.exists(vehicle_test_path):
        os.mkdir(vehicle_test_path)
    else:
        continue
        
    vehicle_train_path = os.path.join(TRAIN_PATH, row['name'])
    if not os.path.exists(vehicle_train_path):
        os.mkdir(vehicle_train_path)
    else:
        continue
        
    origin = os.path.join(ROOT, row['name'])
    imgs_front = [os.path.join(origin, 'front', x) for x in os.listdir(os.path.join(origin, 'front')) if x != '.DS_Store']
    imgs_back = [os.path.join(origin, 'back', x) for x in os.listdir(os.path.join(origin, 'back')) if x != '.DS_Store']
    imgs_side = [os.path.join(origin, 'side', x) for x in os.listdir(os.path.join(origin, 'side')) if x != '.DS_Store']
    imgs_mix = [os.path.join(origin, 'mix', x) for x in os.listdir(os.path.join(origin, 'mix')) if x != '.DS_Store']
    imgs_side += imgs_mix
        
    if (len(imgs_front) + len(imgs_back) + len(imgs_side)) < 1200:
#         curr_augs = [os.path.join(origin, x) for x in front_augs if os.path.exists(os.path.join(origin, x))]
#         extra_data = [[os.path.join(x, y) for y in os.listdir(x) if '.DS_Store' not in y] for x in curr_augs]
#         extra_data = [item for sublist in extra_data for item in sublist]
#         random.shuffle(extra_data)
#         print(f'frontAug: {row["frontAug"]} out of {len(extra_data)}')
#         imgs_front += extra_data[:row['frontAug']]
        imgs_front += [os.path.join(origin, 'front_hflip', x) for x in os.listdir(os.path.join(origin, 'front_hflip')) if x != '.DS_Store']
              
#         curr_augs = [os.path.join(origin, x) for x in back_augs if os.path.exists(os.path.join(origin, x))]
#         extra_data = [[os.path.join(x, y) for y in os.listdir(x) if '.DS_Store' not in y] for x in curr_augs]
#         extra_data = [item for sublist in extra_data for item in sublist]
#         random.shuffle(extra_data)
#         print(f'backAug: {row["backAug"]} out of {len(extra_data)}')
#         imgs_back += extra_data[:row['backAug']]
        imgs_back += [os.path.join(origin, 'back_hflip', x) for x in os.listdir(os.path.join(origin, 'back_hflip')) if x != '.DS_Store']
              
#         curr_augs = [os.path.join(origin, x) for x in side_augs if os.path.exists(os.path.join(origin, x))]
#         extra_data = [[os.path.join(x, y) for y in os.listdir(x) if '.DS_Store' not in y] for x in curr_augs]
#         extra_data = [item for sublist in extra_data for item in sublist]
#         random.shuffle(extra_data)
#         print(f'sideAug: {row["sideAug"]} out of {len(extra_data)}')
#         imgs_side += extra_data[:row['sideAug']]
        imgs_side += [os.path.join(origin, 'side_hflip', x) for x in os.listdir(os.path.join(origin, 'side_hflip')) if x != '.DS_Store']
              
    imgs_all = imgs_front + imgs_back + imgs_side
    if len(imgs_all) < 1200:
        shutil.rmtree(vehicle_test_path, ignore_errors=True)
        shutil.rmtree(vehicle_train_path, ignore_errors=True)
        continue
#         raise ValueError(f'{origin} - not enough images, {len(imgs_all)}')

    random.shuffle(imgs_all)
    
    for im_path in imgs_all[:1000]:
        try:
            rand_name = f'{random_string(20)}-{random.randint(1, limit)}.jpg'
            target_path = os.path.join(vehicle_train_path, rand_name)
            while os.path.exists(target_path):
                target_path = os.path.join(vehicle_train_path, rand_name)
                print(f'{target_path} already exists (train)')
            shutil.copy2(im_path, target_path)
        except Exception as e:
            print(e)
    
    assert(len([x for x in os.listdir(vehicle_train_path) if x != '.DS_Store']) >= 1000)

    for im_path in imgs_all[1000:1200]:
        try:
            rand_name = f'{random_string(20)}-{random.randint(1, limit)}.jpg'
            target_path = os.path.join(vehicle_test_path, rand_name)
            while os.path.exists(target_path):
                target_path = os.path.join(vehicle_test_path, rand_name)
                print(f'{target_path} already exists (test)')
            shutil.copy2(im_path, target_path)
        except Exception as e:
            print(e)
              
    assert(len([x for x in os.listdir(vehicle_test_path) if x != '.DS_Store']) >= 200)
    # failed at 쉐보레(GM대우)토스카토스카프리미엄6(08~11년)
# Out:
# 기아레이레이(11~17년)
# 기아스포티지스포티지R(10~13년)
# 기아모닝올뉴모닝(11~15년)
# 기아카니발올뉴카니발(14~18년)
# 현대아반떼더뉴아반떼AD(18년~현재)
# 기아스포티지더뉴스포티지R(13~15년)
# 기아카니발그랜드카니발(05~10년)
# 기아쏘렌토올뉴쏘렌토(14~17년)
# 르노삼성SM6SM6(16년~현재)
# 기아K5K52세대(15~18년)
# 기아K5더뉴K5(13~15년)
# 기아모닝올뉴모닝(JA)(17년~현재)
# 기아스포티지스포티지4세대(15~18년)
# 기아K7더뉴K7(12~16년)
# BMW5시리즈5시리즈(F10)(10~16년)
# 기아K7올뉴K7(16년~현재)
# 기아쏘렌토쏘렌토R(09~12년)
# 기아모하비모하비(07~16년)
# 현대쏘나타LF쏘나타(14~17년)
# 현대쏘나타쏘나타(DN8)(19년~현재)
# 현대투싼올뉴투싼(15년~현재)
# 기아카니발카니발R(10~14년)
# 제네시스G80G80(16년~현재)
# 제네시스EQ900EQ900(15~18년)
# 현대쏘나타YF쏘나타(09~12년)
# 현대쏘나타쏘나타하이브리드(11~14년)
# 현대아반떼아반떼MD(10~13년)
# 현대싼타페싼타페CM(05~12년)
# 현대아반떼아반떼HD(06~10년)
# 기아스포티지New스포티지(04~10년)
# 현대싼타페싼타페DM(12~15년)
# 르노삼성SM3뉴SM3(09~14년)
# 기아니로니로(16~19년)
# 기아모닝더뉴모닝(15~17년)
# 르노삼성SM5뉴SM5플래티넘(12~15년)
# 쉐보레(GM대우)스파크스파크(11~15년)
# 쉐보레(GM대우)스파크더넥스트스파크(15~18년)
# 현대아반떼아반떼AD(15~18년)
# 기아모닝뉴모닝(08~11년)
# 기아쏘렌토뉴쏘렌토R(12~14년)
# 현대싼타페싼타페TM(18년~현재)
# 기아K7K7(09~11년)
# 기아K7더프레스티지K7(11~12년)
# 기아모하비더뉴모하비(16년~현재)
# 기아카렌스뉴카렌스(06~13년)
# 현대싼타페싼타페더프라임(15~18년)
# 현대제네시스제네시스(08~13년)
# 르노삼성SM5뉴SM5(신형)(10~12년)
# 현대그랜저그랜저TG(05~08년)
# 르노삼성QM3QM3(13~17년)
# 기아K3K3(12~15년)
# 기아로체로체이노베이션(08~10년)
# 르노삼성SM3SM3네오(14년~현재)
# 쌍용티볼리티볼리(15~17년)
# 기아K3더뉴K3(15~18년)
# 현대그랜저그랜저HG(11~16년)
# 기아오피러스뉴오피러스(06~09년)
# 기아쏘렌토더뉴쏘렌토(17년~현재)
# 쉐보레(GM대우)토스카토스카프리미엄6(08~11년)
# 르노삼성QM6QM6(16년~현재)
# 쉐보레(GM대우)트랙스트랙스(13~16년)
# 기아쏘렌토쏘렌토(02~06년)
# BMW3시리즈3시리즈(G20)(19년~현재)
# 쉐보레(GM대우)라세티라세티프리미어(08~11년)
# 르노삼성SM5SM5뉴임프레션(07~10년)
# 르노삼성SM7SM7(04~08년)
# 벤츠C-클래스C-클래스W205(14년~현재)
# 기아쏘울쏘울(08~13년)
# 현대스타렉스그랜드스타렉스(07~17년)
# 지프랭글러랭글러(JK)(07~18년)
# 쉐보레(GM대우)말리부올뉴말리부(16~18년)
# 현대제네시스제네시스DH(13~16년)
# 기아카렌스카렌스II(02~06년)
# 르노삼성SM5SM5(98~05년)
# 렉서스ISIS250(05~13년)
# 기아쏘렌토뉴쏘렌토(06~09년)
# 르노삼성SM7SM7NewArt(08~11년)
# 기아K5K5하이브리드(11~15년)
# 아우디A6뉴A6(04년~현재)
# BMW6시리즈6시리즈(F12)(11년~현재)
# 기아프라이드올뉴프라이드(11~15년)
# 현대투스카니투스카니(신형)(06~08년)
# 기아오피러스오피러스프리미엄(09~11년)
# 기아K9더뉴K9(14~18년)
# 기아스팅어스팅어(17년~현재)
# 지프체로키그랜드체로키(93년~현재)
# 르노삼성SM5뉴SM5(05~07년)

# %%
train_path = '/Volumes/TriveStorage/code/trive-image-recognition/complete_manual/cars_refined/train'
test_path = '/Volumes/TriveStorage/code/trive-image-recognition/complete_manual/cars_refined/test'

for folder in [os.path.join(train_path, x) for x in os.listdir(train_path) if x != '.DS_Store']:
    length = len([x for x in os.listdir(folder) if x != '.DS_Store'])
    if length != 1000:
        print(folder)
        print(length)
        print('\n')

for folder in [os.path.join(test_path, x) for x in os.listdir(train_path) if x != '.DS_Store']:
    length = len([x for x in os.listdir(folder) if x != '.DS_Store'])
    if length != 200:
        print(folder)
        print(length)
        print('\n')

# %%
#             save_to_gray(im_path, os.path.join(vehicle_test_path, rand_name))
