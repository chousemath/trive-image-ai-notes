# %% [markdown]
# # Clean AutoHub Images
#
# * Question: Why was the experiment conducted?.
# > Answer: in progress...
#
# * Question: What specific problem/research question was being addressed?
# > Answer: in progress...
#
# * Question: What methods were used to solve the problem/answer the question?
# > Answer: in progress...
#
# * Question: What results were obtained?
# > Answer: in progress...
#
# * Question: What do these results mean?
# > Answer: in progress...
#
# * Question: How do they answer the overall question or improve our understanding of the problem?
# > Answer: in progress...

# %%
# import all dependencies here
from imageai.Prediction.Custom import CustomImagePrediction
import os
import random
import shutil
from pprint import pprint

# %%
p = CustomImagePrediction()
p.setModelTypeAsResNet()
path_to_resnet = 'vehicle_direction.h5'
path_to_models = 'vehicle_direction.json'
p.setModelPath(path_to_resnet)
p.setJsonPath(path_to_models)
p.loadModel(num_objects=5)
# Out:
# WARNING:tensorflow:From /Users/jo/anaconda3/envs/data/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
base_paths = [
    '/Volumes/TriveStorage/code/trive-image-recognition/complete_manual/phone_videos',
#     '/Volumes/TriveStorage/code/trive-image-recognition/complete_manual/youtube',
#     '/Volumes/TriveStorage/code/trive-image-recognition/complete_manual/encar_latest',
]
# base_path = '/Volumes/TriveStorage/code/trive-image-recognition/complete_manual/youtube_temporary'

already_checked = {}

while True:
    for base_path in base_paths:
        roots = [os.path.join(base_path, x) for x in os.listdir(base_path) if x != '.DS_Store']
        for root in roots:
            for path in [os.path.join(root, x) for x in os.listdir(root) if x != '.DS_Store']:
                if path in already_checked or not os.path.exists(path):
                    continue
                try:
                    predictions, probabilities = p.predictImage(path, result_count=1)
                    if predictions[0] == 'trash':
                        os.remove(path)
                        print('removed: ', path)
                    else:
                        already_checked[path] = True
                except Exception as e:
                    print(e)
# Out:
# removed:  /Volumes/TriveStorage/code/trive-image-recognition/complete_manual/phone_videos/11나5879/1129696823696412566.jpg
# [Errno 2] No such file or directory: '/Volumes/TriveStorage/code/trive-image-recognition/complete_manual/phone_videos/11나5879/1564283301973903987.jpg'
# removed:  /Volumes/TriveStorage/code/trive-image-recognition/complete_manual/phone_videos/11나5879/1979265347762070687.jpg
# removed:  /Volumes/TriveStorage/code/trive-image-recognition/complete_manual/phone_videos/11나5879/2175170357454509658.jpg
# removed:  /Volumes/TriveStorage/code/trive-image-recognition/complete_manual/phone_videos/11나5879/2183112651055708172.jpg
# removed:  /Volumes/TriveStorage/code/trive-image-recognition/complete_manual/phone_videos/11나5879/2555540709834888451.jpg
# removed:  /Volumes/TriveStorage/code/trive-image-recognition/complete_manual/phone_videos/11나5879/2746663297517837994.jpg
# ...
