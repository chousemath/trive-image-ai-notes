# %%
import os
from pprint import pprint

# %%
src = '/Users/jo/Downloads/1559549170168000.txt'
lines = [line.rstrip('\n').replace('/kiarayray11_17/', 'https://ik.imagekit.io/tfohpbrio/kiarayray11_17/tr:h-200,w-200,fo-auto/') for line in open(src)]
pprint(lines)

# https://ik.imagekit.io/tfohpbrio/kiarayray11_17/20190422Dh18151555897559_1_8FrqL57OZl.jpg
# /tr:h-200,w-200,fo-auto
# Out:
# ['https://ik.imagekit.io/tfohpbrio/kiarayray11_17/tr:h-200,w-200,fo-auto/20180518GA19891526611984_1_DPzRp0VXl.jpg',
#  'https://ik.imagekit.io/tfohpbrio/kiarayray11_17/tr:h-200,w-200,fo-auto/20180509CR17351525844744_1_Sd4NziXpx.jpg',
#  'https://ik.imagekit.io/tfohpbrio/kiarayray11_17/tr:h-200,w-200,fo-auto/20180513AB16091526215125_2_xPDwwU_J_2.jpg',
#  'https://ik.imagekit.io/tfohpbrio/kiarayray11_17/tr:h-200,w-200,fo-auto/20180528Bg12731527472440_1_p0yJPZnwh.jpg',
#  'https://ik.imagekit.io/tfohpbrio/kiarayray11_17/tr:h-200,w-200,fo-auto/20180528HA16171527489615_1_e0rMxHxCGX.jpg',
#  'https://ik.imagekit.io/tfohpbrio/kiarayray11_17/tr:h-200,w-200,fo-auto/20180608GB19621528432024_1_tja9BoRkS.jpg',
#  'https://ik.imagekit.io/tfohpbrio/kiarayray11_17/tr:h-200,w-200,fo-auto/20180611GR18581528681930_1_NAjnrThm9r.jpg',
#  'https://ik.imagekit.io/tfohpbrio/kiarayray11_17/tr:h-200,w-200,fo-auto/20180528GB14301527473901_1_43gs4cK-T8.jpg',
# ...
